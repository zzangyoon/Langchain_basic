# %%
from dotenv import load_dotenv
load_dotenv()

import os
project_name = "wanted_2nd_langchain_basic"
os.environ["LANGSMITH_PROJECT"] = project_name

# %%
from langchain_openai import ChatOpenAI

model = ChatOpenAI(
    temperature=0.1,
    model="gpt-4.1-mini",
    verbose=True
)

# %% [markdown]
# ### 체인 만들기

# %%
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# 프롬프트 템플릿 설정
template = """
최근 {year}년 간 {field} 분야의 기술 발전에 대해서 알려줘
"""
prompt_template = PromptTemplate.from_template(template)

# 모델 설정
model = ChatOpenAI(
    temperature=0.1,
    model="gpt-4.1-mini",
    verbose=True
)

# 아웃풋 파서 설정
outputparser = StrOutputParser()

# 체인 설정
chain = prompt_template | model | outputparser
chain
# Out:
# PromptTemplate(input_variables=['field', 'year'], input_types={}, partial_variables={}, template='\n최근 {year}년 간 {field} 분야의 기술 발전에 대해서 알려줘\n')
# | ChatOpenAI(client=<openai.resources.chat.completions.completions.Completions object at 0x000001DF11224850>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000001DF11242090>, root_client=<openai.OpenAI object at 0x000001DF111F7310>, root_async_client=<openai.AsyncOpenAI object at 0x000001DF0E02D090>, model_name='gpt-4.1-mini', temperature=0.1, model_kwargs={}, openai_api_key=SecretStr('**********'))
# | StrOutputParser()

# %% [markdown]
# 1. invoke 출력
# 2. stream 출력
# 3. batch 출력
# 4. ainvoke
# 5. astream 비동기 출력

# %%
# 배치 단위 출력
response = chain.batch([{"field" : "AI", "year" : 3}, {"field" : "드론", "year" : 3}])
print(response)
# Out:
# ['최근 3년 간(2021년~2024년) AI 분야에서는 여러 중요한 기술 발전과 혁신이 이루어졌습니다. 주요 트렌드와 기술 발전을 요약하면 다음과 같습니다.\n\n1. **대규모 언어 모델(LLM)의 발전**\n   - OpenAI의 GPT-3, GPT-3.5, 그리고 GPT-4 출시로 자연어 처리 능력이 크게 향상되었습니다.\n   - 대규모 언어 모델은 텍스트 생성, 번역, 요약, 코드 작성 등 다양한 작업에서 인간 수준에 가까운 성능을 보여주고 있습니다.\n   - 멀티모달 모델(예: GPT-4는 텍스트와 이미지 입력을 동시에 처리 가능)도 등장하여 AI의 활용 범위가 확대되었습니다.\n\n2. **멀티모달 AI**\n   - 텍스트, 이미지, 음성, 비디오 등 다양한 형태의 데이터를 동시에 이해하고 생성할 수 있는 AI 모델이 발전했습니다.\n   - 예를 들어, OpenAI의 DALL·E 2, Google의 Imagen, Meta의 Make-A-Video 등은 텍스트 설명을 기반으로 고품질 이미지나 영상을 생성할 수 있습니다.\n\n3. **생성형 AI(Generative AI)의 확산**\n   - 텍스트, 이미지, 음악, 영상 등 다양한 콘텐츠를 자동으로 생성하는 AI 기술이 상용화되고 대중화되었습니다.\n   - AI 기반 콘텐츠 제작 도구들이 빠르게 발전하며, 크리에이터와 기업의 생산성을 크게 향상시키고 있습니다.\n\n4. **AI의 효율성 및 친환경성 개선**\n   - 대규모 모델의 높은 연산 비용과 에너지 소비 문제를 해결하기 위해 경량화, 지식 증류, 효율적인 학습 알고리즘 개발이 활발히 진행되고 있습니다.\n   - 하드웨어 측면에서도 AI 전용 칩과 가속기가 발전하여 처리 속도와 에너지 효율이 개선되고 있습니다.\n\n5. **자율 시스템과 로보틱스**\n   - 자율주행차, 드론, 로봇 등에서 AI 기술이 더욱 정교해지고 실용화 단계에 접어들었습니다.\n   - 강화학습과 시뮬레이션 기술의 발전으로 복잡한 환경에서의 의사결정 능력이 향상되었습니다.\n\n6. **AI 윤리 및 규제 강화**\n   - AI의 사회적 영향에 대한 관심이 높아지면서, 투명성, 공정성, 프라이버시 보호, 책임성 등을 보장하기 위한 윤리적 가이드라인과 법적 규제가 강화되고 있습니다.\n   - 각국 정부와 국제기구가 AI 규제 정책을 마련하고 있으며, 기업들도 자체적인 윤리 기준을 도입하고 있습니다.\n\n7. **응용 분야의 확장**\n   - 의료, 금융, 교육, 제조, 고객 서비스 등 다양한 산업에서 AI 도입이 가속화되고 있습니다.\n   - 특히 의료 분야에서는 AI 기반 진단, 신약 개발, 맞춤형 치료 등이 활발히 연구되고 있습니다.\n\n요약하자면, 최근 3년간 AI는 대규모 언어 모델과 멀티모달 AI의 발전을 중심으로 생성형 AI가 대중화되고, 효율성과 윤리 문제에 대한 관심이 높아지면서 다양한 산업에 깊숙이 침투하는 중요한 전환기를 맞이하고 있습니다.', '최근 3년 간(2021년~2024년) 드론 분야에서는 여러 기술적 발전이 이루어졌습니다. 주요 트렌드와 기술 발전 내용을 정리하면 다음과 같습니다.\n\n1. **자율비행 및 인공지능(AI) 적용 강화**\n   - 드론의 자율비행 능력이 크게 향상되었습니다. AI와 머신러닝 기술을 활용해 장애물 회피, 경로 최적화, 실시간 환경 인식 등이 가능해졌습니다.\n   - 딥러닝 기반 영상 인식 기술이 발전하면서 드론이 사람, 차량, 동물 등을 자동으로 식별하고 추적하는 기능이 보편화되었습니다.\n\n2. **배터리 및 비행 시간 개선**\n   - 고에너지 밀도의 배터리 개발과 효율적인 전력 관리 기술 덕분에 드론의 비행 시간이 연장되었습니다.\n   - 수소 연료전지 드론, 태양광 드론 등 대체 에너지 기반 드론 연구도 활발히 진행되어 장시간 비행이 가능해졌습니다.\n\n3. **통신 및 네트워크 기술 발전**\n   - 5G 및 저지연 통신 기술이 드론에 적용되어 원격 조종과 실시간 데이터 전송이 더욱 안정적이고 빠르게 이루어지고 있습니다.\n   - 드론 군집 비행(드론 스웜) 기술이 발전하여 여러 대의 드론이 협력해 임무를 수행하는 사례가 증가하고 있습니다.\n\n4. **산업별 맞춤형 드론 솔루션 확대**\n   - 농업, 건설, 물류, 재난 대응, 환경 모니터링 등 다양한 산업 분야에 특화된 드론 솔루션이 개발되고 있습니다.\n   - 예를 들어, 농업용 드론은 정밀 농업을 위해 작물 상태 분석, 농약 살포 자동화 기능이 강화되었습니다.\n\n5. **규제 및 안전 기술 발전**\n   - 드론 비행 안전을 위한 충돌 방지 시스템, 비행 제한 구역 자동 인식 기술 등이 발전했습니다.\n   - 각국 정부가 드론 운용 규제를 체계화하면서, 드론 등록, 비행 허가, 교통 관리 시스템(UTM, Unmanned Traffic Management) 구축이 진행되고 있습니다.\n\n6. **하드웨어 성능 향상**\n   - 소형화, 경량화된 고성능 센서(카메라, LiDAR, 적외선 센서 등)가 드론에 탑재되어 정밀한 데이터 수집이 가능해졌습니다.\n   - 모터와 프로펠러 효율 개선으로 안정적인 비행과 소음 저감 효과도 나타나고 있습니다.\n\n요약하면, 최근 3년간 드론 기술은 AI 기반 자율비행, 배터리 효율 향상, 5G 통신 적용, 산업별 맞춤 솔루션 확대, 안전 규제 강화, 그리고 하드웨어 성능 개선을 중심으로 빠르게 발전하고 있습니다. 이러한 발전은 드론의 활용 범위를 넓히고, 상업적·산업적 가치 증대에 크게 기여하고 있습니다.']

# %%
for i in response:
    print(i)
    print("-"*50)
# Out:
# 최근 3년 간(2021년~2024년) AI 분야에서는 여러 중요한 기술 발전과 혁신이 이루어졌습니다. 주요 트렌드와 기술 발전을 요약하면 다음과 같습니다.
#
# 1. **대규모 언어 모델(LLM)의 발전**
#    - OpenAI의 GPT-3, GPT-3.5, 그리고 GPT-4 출시로 자연어 처리 능력이 크게 향상되었습니다.
#    - 대규모 언어 모델은 텍스트 생성, 번역, 요약, 코드 작성 등 다양한 작업에서 인간 수준에 가까운 성능을 보여주고 있습니다.
#    - 멀티모달 모델(예: GPT-4는 텍스트와 이미지 입력을 동시에 처리 가능)도 등장하여 AI의 활용 범위가 확대되었습니다.
#
# 2. **멀티모달 AI**
#    - 텍스트, 이미지, 음성, 비디오 등 다양한 형태의 데이터를 동시에 이해하고 생성할 수 있는 AI 모델이 발전했습니다.
#    - 예를 들어, OpenAI의 DALL·E 2, Google의 Imagen, Meta의 Make-A-Video 등은 텍스트 설명을 기반으로 고품질 이미지나 영상을 생성할 수 있습니다.
#
# 3. **생성형 AI(Generative AI)의 확산**
#    - 텍스트, 이미지, 음악, 영상 등 다양한 콘텐츠를 자동으로 생성하는 AI 기술이 상용화되고 대중화되었습니다.
#    - AI 기반 콘텐츠 제작 도구들이 빠르게 발전하며, 크리에이터와 기업의 생산성을 크게 향상시키고 있습니다.
#
# 4. **AI의 효율성 및 친환경성 개선**
#    - 대규모 모델의 높은 연산 비용과 에너지 소비 문제를 해결하기 위해 경량화, 지식 증류, 효율적인 학습 알고리즘 개발이 활발히 진행되고 있습니다.
#    - 하드웨어 측면에서도 AI 전용 칩과 가속기가 발전하여 처리 속도와 에너지 효율이 개선되고 있습니다.
#
# 5. **자율 시스템과 로보틱스**
#    - 자율주행차, 드론, 로봇 등에서 AI 기술이 더욱 정교해지고 실용화 단계에 접어들었습니다.
#    - 강화학습과 시뮬레이션 기술의 발전으로 복잡한 환경에서의 의사결정 능력이 향상되었습니다.
#
# 6. **AI 윤리 및 규제 강화**
#    - AI의 사회적 영향에 대한 관심이 높아지면서, 투명성, 공정성, 프라이버시 보호, 책임성 등을 보장하기 위한 윤리적 가이드라인과 법적 규제가 강화되고 있습니다.
#    - 각국 정부와 국제기구가 AI 규제 정책을 마련하고 있으며, 기업들도 자체적인 윤리 기준을 도입하고 있습니다.
#
# 7. **응용 분야의 확장**
#    - 의료, 금융, 교육, 제조, 고객 서비스 등 다양한 산업에서 AI 도입이 가속화되고 있습니다.
#    - 특히 의료 분야에서는 AI 기반 진단, 신약 개발, 맞춤형 치료 등이 활발히 연구되고 있습니다.
#
# 요약하자면, 최근 3년간 AI는 대규모 언어 모델과 멀티모달 AI의 발전을 중심으로 생성형 AI가 대중화되고, 효율성과 윤리 문제에 대한 관심이 높아지면서 다양한 산업에 깊숙이 침투하는 중요한 전환기를 맞이하고 있습니다.
# --------------------------------------------------
# 최근 3년 간(2021년~2024년) 드론 분야에서는 여러 기술적 발전이 이루어졌습니다. 주요 트렌드와 기술 발전 내용을 정리하면 다음과 같습니다.
#
# 1. **자율비행 및 인공지능(AI) 적용 강화**
#    - 드론의 자율비행 능력이 크게 향상되었습니다. AI와 머신러닝 기술을 활용해 장애물 회피, 경로 최적화, 실시간 환경 인식 등이 가능해졌습니다.
#    - 딥러닝 기반 영상 인식 기술이 발전하면서 드론이 사람, 차량, 동물 등을 자동으로 식별하고 추적하는 기능이 보편화되었습니다.
#
# 2. **배터리 및 비행 시간 개선**
#    - 고에너지 밀도의 배터리 개발과 효율적인 전력 관리 기술 덕분에 드론의 비행 시간이 연장되었습니다.
#    - 수소 연료전지 드론, 태양광 드론 등 대체 에너지 기반 드론 연구도 활발히 진행되어 장시간 비행이 가능해졌습니다.
#
# 3. **통신 및 네트워크 기술 발전**
#    - 5G 및 저지연 통신 기술이 드론에 적용되어 원격 조종과 실시간 데이터 전송이 더욱 안정적이고 빠르게 이루어지고 있습니다.
#    - 드론 군집 비행(드론 스웜) 기술이 발전하여 여러 대의 드론이 협력해 임무를 수행하는 사례가 증가하고 있습니다.
#
# 4. **산업별 맞춤형 드론 솔루션 확대**
#    - 농업, 건설, 물류, 재난 대응, 환경 모니터링 등 다양한 산업 분야에 특화된 드론 솔루션이 개발되고 있습니다.
#    - 예를 들어, 농업용 드론은 정밀 농업을 위해 작물 상태 분석, 농약 살포 자동화 기능이 강화되었습니다.
#
# 5. **규제 및 안전 기술 발전**
#    - 드론 비행 안전을 위한 충돌 방지 시스템, 비행 제한 구역 자동 인식 기술 등이 발전했습니다.
#    - 각국 정부가 드론 운용 규제를 체계화하면서, 드론 등록, 비행 허가, 교통 관리 시스템(UTM, Unmanned Traffic Management) 구축이 진행되고 있습니다.
#
# 6. **하드웨어 성능 향상**
#    - 소형화, 경량화된 고성능 센서(카메라, LiDAR, 적외선 센서 등)가 드론에 탑재되어 정밀한 데이터 수집이 가능해졌습니다.
#    - 모터와 프로펠러 효율 개선으로 안정적인 비행과 소음 저감 효과도 나타나고 있습니다.
#
# 요약하면, 최근 3년간 드론 기술은 AI 기반 자율비행, 배터리 효율 향상, 5G 통신 적용, 산업별 맞춤 솔루션 확대, 안전 규제 강화, 그리고 하드웨어 성능 개선을 중심으로 빠르게 발전하고 있습니다. 이러한 발전은 드론의 활용 범위를 넓히고, 상업적·산업적 가치 증대에 크게 기여하고 있습니다.
# --------------------------------------------------

# %%
# ainvoke 비동기 출력
async_answer = chain.ainvoke({"field" : "AI", "year" : 3})

# %%
result = await async_answer
result
# Out:
# '최근 3년 간(2021년~2024년) AI 분야에서는 여러 중요한 기술 발전과 혁신이 이루어졌습니다. 주요 트렌드와 기술 발전을 요약하면 다음과 같습니다.\n\n1. **대규모 언어 모델(LLM)의 발전**\n   - OpenAI의 GPT-3(2020년 출시) 이후, GPT-4(2023년 출시) 등 더욱 정교하고 강력한 대규모 언어 모델이 등장했습니다.\n   - 멀티모달 모델(텍스트, 이미지, 음성 등 다양한 입력을 동시에 처리하는 모델)이 발전하여, 예를 들어 GPT-4는 텍스트와 이미지를 함께 이해하고 생성할 수 있습니다.\n   - 이러한 모델들은 자연어 이해, 생성, 번역, 요약, 코드 작성 등 다양한 분야에서 활용도가 크게 증가했습니다.\n\n2. **생성형 AI(Generative AI)의 확산**\n   - 텍스트뿐 아니라 이미지, 음악, 영상 생성 AI가 크게 발전했습니다.\n   - 대표적으로 OpenAI의 DALL·E 2, Stability AI의 Stable Diffusion, Google의 Imagen 등이 고품질 이미지를 생성하며, 크리에이티브 산업에 혁신을 가져왔습니다.\n   - 생성형 AI는 콘텐츠 제작, 디자인, 게임, 광고 등 다양한 산업에서 활용되고 있습니다.\n\n3. **멀티모달 AI와 통합 AI 시스템**\n   - 텍스트, 이미지, 음성, 영상 등 여러 형태의 데이터를 동시에 처리하는 멀티모달 AI가 상용화 단계에 진입했습니다.\n   - 예를 들어, Meta, Google, OpenAI 등에서 멀티모달 모델을 연구 및 배포하며, 사용자 인터페이스와 경험을 혁신하고 있습니다.\n\n4. **AI의 효율성 및 친환경성 개선**\n   - 대규모 모델의 높은 연산 비용과 에너지 소비 문제를 해결하기 위해, 경량화 모델, 지식 증류, 효율적인 학습 알고리즘 등이 활발히 연구되고 있습니다.\n   - 하드웨어 측면에서도 AI 전용 칩과 가속기가 발전하여, AI 연산의 효율성이 크게 향상되었습니다.\n\n5. **AI 윤리 및 규제 강화**\n   - AI의 사회적 영향력 확대에 따라, 윤리적 문제, 편향성, 개인정보 보호, 투명성 등에 대한 관심과 규제가 강화되고 있습니다.\n   - 여러 국가와 국제기구에서 AI 규제 프레임워크를 마련하고, 책임 있는 AI 개발과 활용을 촉진하고 있습니다.\n\n6. **특화 AI 및 산업별 AI 적용 확대**\n   - 의료, 금융, 제조, 자율주행, 로보틱스 등 특정 산업에 특화된 AI 솔루션과 모델이 발전했습니다.\n   - 예를 들어, 의료 영상 분석 AI, 금융 리스크 평가 AI, 자율주행차용 AI 시스템 등이 상용화 및 실험 단계에 있습니다.\n\n7. **자기지도학습(Self-supervised Learning)과 강화학습 발전**\n   - 라벨이 없는 데이터로부터 학습하는 자기지도학습 기법이 더욱 정교해져, 데이터 효율성이 크게 개선되었습니다.\n   - 강화학습도 복잡한 환경에서의 의사결정 및 전략 수립에 적용 범위가 넓어지고 있습니다.\n\n요약하면, 최근 3년간 AI는 대규모 언어 모델과 생성형 AI의 비약적 발전, 멀티모달 AI의 상용화, 효율성 개선, 윤리적 규제 강화, 그리고 산업별 특화 AI의 확산이라는 주요 흐름을 중심으로 빠르게 진화하고 있습니다.'
